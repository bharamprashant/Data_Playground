# %%
import pandas as pd
import json

# %%
df  = pd.read_json('/home/prashant/Downloads/pcinde_master_fullerton (3).json')

# %%
df.T
# Out:
#                                                         city  \
# data       [West Godavari, Achanta, Adoni, Ajjada, Ananta...
# timestamp                                2018-05-19 18:09:29
#
#                                                     district  \
# data       [West Godavari, West Godavari, Kurnool, Srikak...
# timestamp                                2018-05-19 18:09:29
#
#                                                     pin_code  \
# data       [534448, 534123, 518301, 532552, 515001, 51500...
# timestamp                                2018-05-19 18:09:29
#
#                                                        state
# data       [Andhra Pradesh, Andhra Pradesh, Andhra Prades...
# timestamp                                2018-05-19 18:09:29

# %%
with open ('/home/prashant/Downloads/converted_json.csv') as f:
    print(f.read())
# Out:
# ,data,timestamp
# ...

# %%
df.to_csv('/home/prashant/Downloads/converted_json.csv')
