# %%
import pandas as pd

# %%
all_data = pd.read_csv('/home/prashant/Downloads/pincode/pin_codes.csv')

# %%
all_data.head()
# Out:
#    pincode   districtname statename  serviceable
# 0   110001  Central Delhi     DELHI            1
# 1   110002  Central Delhi     DELHI            1
# 2   110003  Central Delhi     DELHI            1
# 3   110004  Central Delhi     DELHI            1
# 4   110005  Central Delhi     DELHI            1

# %%
type(all_data.pincode)
# Out:
# pandas.core.series.Series

# %%
# serviceable = all_data[all_data['serviceable']==1]
# len(serviceable)

# %%
serviceable_district = all_data[all_data['serviceable'] == 1]['districtname'].unique()

# %%
serviceable_district
# Out:
# array(['Central Delhi', 'North Delhi', 'North West Delhi',
#        'South West Delhi', 'South Delhi', 'West Delhi', 'East Delhi',
#        'North East Delhi', 'New Delhi', 'Gurgaon', 'Faridabad',
#        'Panchkula', 'Mohali', 'Chandigarh', 'Ghaziabad',
#        'Gautam Buddha Nagar', 'Jaipur', 'Ahmedabad', 'Gandhi Nagar',
#        'Mumbai', 'Thane', 'Pune', 'Nashik', 'Hyderabad', 'K.V.Rangareddy',
#        'Bengaluru', 'Bangalore Rural', 'Kolar', 'Chennai', 'Kanchipuram',
#        'Tiruvallur', 'Kolkata', 'Howrah', 'Hooghly'], dtype=object)

# %%
cityname_map = {'Central Delhi' :'Delhi', 'North Delhi' :'Delhi', 'North West Delhi' :'Delhi',
       'South West Delhi' :'Delhi', 'South Delhi' :'Delhi', 'West Delhi' :'Delhi', 'East Delhi' :'Delhi',
       'North East Delhi' :'Delhi', 'New Delhi' :'Delhi', 'Gurgaon': 'Gurgaon', 'Faridabad': 'Faridabad',
       'Panchkula' : 'Panchkula', 'Mohali': 'Mohali', 'Chandigarh':'Chandigarh', 'Ghaziabad':'Ghaziabad',
       'Gautam Buddha Nagar': 'Noida', 'Jaipur': 'Jaipur', 'Ahmedabad': 'Ahmedabad', 'Gandhi Nagar': 'Gandhi Nagar',
       'Mumbai': 'Mumbai', 'Thane': 'Thane', 'Pune':'Pune', 'Nashik': 'Nashik', 'Hyderabad': 'Hyderabad', 'K.V.Rangareddy':'Hyderabad',
       'Bengaluru':'Bengaluru', 'Bangalore Rural':'Bengaluru', 'Kolar':'Kolar', 'Chennai':'Chennai', 'Kanchipuram': 'Kanchipuram',
       'Tiruvallur':'Tiruvallur', 'Kolkata': 'Kolkata', 'Howrah': 'Howrah', 'Hooghly':'Hooghly'}

# %%
# serviceable['cityname'] = serviceable['districtname'].apply(lambda dist:cityname_map.get(dist,dist))

# %%
# len(serviceable)

# %%
# serviceable.head()

# %%
# serviceable[serviceable.cityname.isnull()]

# %%
# non_serviceable = all_data[all_data['serviceable']==0]
# len(non_serviceable)

# %%
# non_serviceable.head()

# %%
# non_serviceable.cityname = non_serviceable.districtname

# %%
# non_serviceable.head()

# %%
def fn(row):
    if row.serviceable == 1:
        return cityname_map.get(row.districtname, row.districtname)
    else:
        return row.districtname

# %%
all_data['cityname'] = all_data.apply(fn, axis=1)

# %%
all_data
# Out:
#        pincode      districtname statename  serviceable    cityname
# 0       110001     Central Delhi     DELHI            1       Delhi
# 1       110002     Central Delhi     DELHI            1       Delhi
# 2       110003     Central Delhi     DELHI            1       Delhi
# 3       110004     Central Delhi     DELHI            1       Delhi
# 4       110005     Central Delhi     DELHI            1       Delhi
# 5       110006     Central Delhi     DELHI            1       Delhi
# 6       110007       North Delhi     DELHI            1       Delhi
# 7       110008     Central Delhi     DELHI            1       Delhi
# 8       110009  North West Delhi     DELHI            1       Delhi
# 9       110010  South West Delhi     DELHI            1       Delhi
# 10      110011     Central Delhi     DELHI            1       Delhi
# 11      110012     Central Delhi     DELHI            1       Delhi
# 12      110013       South Delhi     DELHI            1       Delhi
# ...

# %%
all_data[all_data.cityname.isnull()]
# Out:
# Empty DataFrame
# Columns: [pincode, districtname, statename, serviceable, cityname]
# Index: []

# %%
all_data.to_csv('/home/prashant/Downloads/pincode/all_data_city_mapped.csv')
