# %%
import pandas as pd

# %%
data = pd.read_csv('/home/prashant/Downloads/Apoorv_DMI/non_uc_case_pf.csv')

# %%
data.columns
# Out:
# Index(['app_id', 'loanid', 'lenderid', 'amount', 'processing_fee'], dtype='object')

# %%
data.head()

# %%
data['calc_pro_fee'] = data.amount * 0.03

# %%
data
# Out:
#      app_id  loanid  lenderid    amount  processing_fee  calc_pro_fee
# 0       364      21       174  175000.0          3000.0        5250.0
# 1      1174     143       174  150000.0          3000.0        4500.0
# 2      2057     394       174  100000.0           300.0        3000.0
# 3      2689     493       174   50000.0          1725.0        1500.0
# 4       261     162       176   50000.0          4728.0        1500.0
# 5      2983     594       174  175000.0          4500.0        5250.0
# 6      7182    1122       174   80000.0          2832.0        2400.0
# 7      7140    1142       174   80000.0          2832.0        2400.0
# 8      7143    1180       174   80000.0          2832.0        2400.0
# 9      6716    1192       174   50000.0          1700.0        1500.0
# 10     7934    1214       174   55000.0          1947.0        1650.0
# 11     7372    1234       174   50000.0          1770.0        1500.0
# ...

# %%
data.to_csv('/home/prashant/Downloads/Apoorv_DMI/final_pro_fee_non_uc.csv')
