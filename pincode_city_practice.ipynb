# %%
import pandas as pd
import numpy as np

# %%
# table_1 = pd.read_csv('/home/prashant/Downloads/pincode/mapped_with_City_1.csv', index_col=['pincode'])
table_1 = pd.read_csv('/home/prashant/Downloads/pincode/mapped_with_City_1.csv')
table_1.head()
# Out:
#    pincode   districtname statename  serviceable cityname
# 0   110001  Central Delhi     DELHI            1    Delhi
# 1   110002  Central Delhi     DELHI            1    Delhi
# 2   110003  Central Delhi     DELHI            1    Delhi
# 3   110004  Central Delhi     DELHI            1    Delhi
# 4   110005  Central Delhi     DELHI            1    Delhi

# %%
# table_2 = pd.read_csv('/home/prashant/Downloads/pincode/pin_codes.csv', index_col=['pincode'])
table_2 = pd.read_csv('/home/prashant/Downloads/pincode/pin_codes.csv')
table_2.head()
# Out:
#    pincode   districtname statename  serviceable cityname
# 0   110001  Central Delhi     DELHI            1      NaN
# 1   110002  Central Delhi     DELHI            1      NaN
# 2   110003  Central Delhi     DELHI            1      NaN
# 3   110004  Central Delhi     DELHI            1      NaN
# 4   110005  Central Delhi     DELHI            1      NaN

# %%
frames = [table_1, table_2]

# %%
table_3 = pd.concat(frames)
table_3.to_csv('/home/prashant/Downloads/pincode/table_3.csv')
table_3
# Out:
#        pincode      districtname statename  serviceable    cityname
# 0       110001     Central Delhi     DELHI            1       Delhi
# 1       110002     Central Delhi     DELHI            1       Delhi
# 2       110003     Central Delhi     DELHI            1       Delhi
# 3       110004     Central Delhi     DELHI            1       Delhi
# 4       110005     Central Delhi     DELHI            1       Delhi
# 5       110006     Central Delhi     DELHI            1       Delhi
# 6       110007       North Delhi     DELHI            1       Delhi
# 7       110008     Central Delhi     DELHI            1       Delhi
# 8       110009  North West Delhi     DELHI            1       Delhi
# 9       110010  South West Delhi     DELHI            1       Delhi
# 10      110011     Central Delhi     DELHI            1       Delhi
# 11      110012     Central Delhi     DELHI            1       Delhi
# 12      110013       South Delhi     DELHI            1       Delhi
# ...

# %%
    # table_3.drop_duplicates(subset='pincode', keep='first')
    # table_3.to_csv('/home/prashant/Downloads/pincode/All_pincode_mapped_with_city.csv')

# %%
# joined_table = table_2.join(table_1, lsuffix='_2', rsuffix='_1')
# joined_table.to_csv('/home/prashant/Downloads/pincode/joined_table')
# joined_table.head()

# %%
# joined_table[~joined_table['cityname_2'].isnull()]
# joined_table['cityname'] = joined_table.apply(lambda r: r['cityname_2'] if not np.isnan(r['cityname_2']) else r['cityname_1'], axis=1)
