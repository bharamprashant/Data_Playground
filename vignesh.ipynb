# %%
import pandas as pd

# %%
data = pd.read_excel("/home/prashant/Downloads/vignesh/FIL.xlsx")

# %%
data
# Out:
#     loan_id  application_id  lender_id  lender_App_id      loan_acc_id
# 0      9974           70662        183        3060395  121311910368297
# 1     10220           75233        183        3081511  121311910367498
# 2     10258           75797        183        3087008   10411910367246
# 3     10285           71642        183        3089668    6811910374658
# 4     10557           75708        183        3106833    3511910368037
# 5     10678           76929        183        3113312  121311910367253
# 6     10893           72241        183        3126773    3511910371563
# 7     10988           77135        183        3124187  121311910370891
# 8     10989           77986        183        3124189  121311910368051
# 9     11058           80655        183        3125875    3511910368044
# 10    11121           81761        183        3133070    6811910367686
# 11    11137           81366        183        3136660  121311910368295
# ...
