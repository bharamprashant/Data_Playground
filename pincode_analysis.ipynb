# %%
import pandas as pd

# %%
data = pd.read_csv('/home/prashant/Downloads/pincode/pin_codes.csv')

# %%
data.head()
# Out:
#    pincode   districtname statename  serviceable
# 0   110001  Central Delhi     DELHI            1
# 1   110002  Central Delhi     DELHI            1
# 2   110003  Central Delhi     DELHI            1
# 3   110004  Central Delhi     DELHI            1
# 4   110005  Central Delhi     DELHI            1

# %%
serviceable = data[data['serviceable'] == 1]
serviceable.head()
serviceable.shape
# Out:
# (1478, 4)

# %%
serviceable_districts = serviceable['districtname'].unique()
serviceable_districts
# Out:
# array(['Central Delhi', 'North Delhi', 'North West Delhi',
#        'South West Delhi', 'South Delhi', 'West Delhi', 'East Delhi',
#        'North East Delhi', 'New Delhi', 'Gurgaon', 'Faridabad',
#        'Panchkula', 'Mohali', 'Chandigarh', 'Ghaziabad',
#        'Gautam Buddha Nagar', 'Jaipur', 'Ahmedabad', 'Gandhi Nagar',
#        'Mumbai', 'Thane', 'Pune', 'Nashik', 'Hyderabad', 'K.V.Rangareddy',
#        'Bengaluru', 'Bangalore Rural', 'Kolar', 'Chennai', 'Kanchipuram',
#        'Tiruvallur', 'Kolkata', 'Howrah', 'Hooghly'], dtype=object)

# %%
cityname_map = {'Central Delhi' : 'Delhi', 'North Delhi' : 'Delhi', 'North West Delhi': 'Delhi', 'South West Delhi': 'Delhi',
                'West Delhi': 'Delhi','East Delhi': 'Delhi','East Delhi': 'Delhi','New Delhi': 'Delhi', 'South Delhi': 'Delhi', 'Gautam Buddha Nagar': 'Noida'
               , 'K.V.Rangareddy': 'Shamshabad', 'Bangalore Rural': 'Bangalore', 'Bangalore Rural': 'Bangalore', 'North East Delhi': 'Delhi'}

# %%
serviceable['cityname'] = serviceable['districtname'].apply(lambda dist: cityname_map.get(dist, dist))
# Out:
# /home/prashant/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
serviceable.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e25c225e5f7f> in <module>()
# ----> 1 serviceable.head()
#
# NameError: name 'serviceable' is not defined

# %%
serviceable.to_csv('out.csv', index=False)

# %%
pin_lat_long = pd.read_csv("/home/prashant/PycharmProjects/medulla/data_models/pincodes.csv")

# %%
pin_lat_long.head()
# Out:
#     latitude   longitude  pincode
# 0  19.864269   79.343739   442901
# 1  19.852595   79.492886   442701
# 2  23.143722  111.785937   441226
# 3  19.918415   80.232131   442604
# 4  20.056226   79.166141   442902

# %%
final = serviceable.set_index('pincode').join(pin_lat_long.set_index('pincode'))
final.columns
# Out:
# Index(['districtname', 'statename', 'serviceable', 'cityname', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
final = final.drop_duplicates()
print(final.shape, final.columns)
absent = final[final['latitude'].apply(lambda x: pd.isnull(x))]
print(absent.shape, absent.columns)
# Out:
# (1153, 6) Index(['districtname', 'statename', 'serviceable', 'cityname', 'latitude',
#        'longitude'],
#       dtype='object')
# (25, 6) Index(['districtname', 'statename', 'serviceable', 'cityname', 'latitude',
#        'longitude'],
#       dtype='object')

# %%
absent['pincode_city'] = absent.apply(lambda row: "{},{}".format(row.cityname, row.name), axis=1)
# Out:
# /home/prashant/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
absent['pincode_city'].values
# Out:
# array(['Delhi,110050', 'Delhi,110098', 'Delhi,110100', 'Gurgaon,120022',
#        'Faridabad,121006', 'Panchkula,134105', 'Chandigarh,160005',
#        'Ghaziabad,201004', 'Noida,201305', 'Jaipur,302004',
#        'Ahmedabad,380003', 'Gandhi Nagar,382009', 'Mumbai,400023',
#        'Thane,401104', 'Pune,411067', 'Hyderabad,500021',
#        'Shamshabad,500104', 'Bengaluru,560044', 'Bangalore,560116',
#        'Chennai,600008', 'Kanchipuram,600016', 'Tiruvallur,600058',
#        'Kolkata,700001', 'Howrah,711102', 'Hooghly,712101'], dtype=object)

# %%
absent.to_csv("/home/prashant/PycharmProjects/medulla/data_models/lat_long_absent_pincodes.csv")

# %%
serviceable1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5e3712e2bf44> in <module>()
# ----> 1 serviceable1.shape
#
# NameError: name 'serviceable1' is not defined

# %%
serviceable.shape

# %%
final.shape

# %%
pin_lat_long1.shape

# %%
absent.index.unique()

# %%
absent

# %%
absent.columns

# %%
frame = pd.DataFrame()

# %%
frame['cityname'] = df['cityname'].unique()

# %%
frame
# Out:
#         cityname
# 0          Delhi
# 1        Gurgaon
# 2      Faridabad
# 3      Panchkula
# 4         Mohali
# 5     Chandigarh
# 6      Ghaziabad
# 7          Noida
# 8         Jaipur
# 9      Ahmedabad
# 10  Gandhi Nagar
# 11        Mumbai
# 12         Thane
# 13          Pune
# 14        Nashik
# 15     Hyderabad
# 16    Shamshabad
# 17     Bengaluru
# 18     Bangalore
# 19         Kolar
# 20       Chennai
# 21   Kanchipuram
# 22    Tiruvallur
# 23       Kolkata
# 24        Howrah
# 25       Hooghly

# %%
df = pd.read_csv("/home/prashant/Downloads/pincode/mapped_with_City.csv")
df['cityname'].unique()
# Out:
# array(['Delhi', 'Gurgaon', 'Faridabad', 'Panchkula', 'Mohali',
#        'Chandigarh', 'Ghaziabad', 'Noida', 'Jaipur', 'Ahmedabad',
#        'Gandhi Nagar', 'Mumbai', 'Thane', 'Pune', 'Nashik', 'Hyderabad',
#        'Shamshabad', 'Bengaluru', 'Bangalore', 'Kolar', 'Chennai',
#        'Kanchipuram', 'Tiruvallur', 'Kolkata', 'Howrah', 'Hooghly'],
#       dtype=object)

# %%
import requests
import json

# %%
URL = "https://maps.googleapis.com/maps/api/geocode/json"

# %%
def get_lat_long(location):
	# defining a params dict for the parameters to be sent to the API
	PARAMS = {'address':location, 'key': "AIzaSyCdN_BqmYYDLUhv9QqO0MrL6qG7L1HUN3M"}
	 
	# sending get request and saving the response as response object
	r = requests.get(url = URL, params = PARAMS)
	 
	# extracting data in json format
	data = r.json()
	print(data)
	# extracting latitude, longitude and formatted address 
	# of the first matching location
    
	latitude = data['results'][0]['geometry']['location']['lat']
	longitude = data['results'][0]['geometry']['location']['lng']
	formatted_address = data['results'][0]['formatted_address']
	 
	# printing the output
	print("Latitude:%s\nLongitude:%s\nFormatted Address:%s"
	      %(latitude, longitude,formatted_address))

	return (latitude, longitude)

# %%
xs = df['cityname'].unique()

# %%
xs
# Out:
# array(['Delhi', 'Gurgaon', 'Faridabad', 'Panchkula', 'Mohali',
#        'Chandigarh', 'Ghaziabad', 'Noida', 'Jaipur', 'Ahmedabad',
#        'Gandhi Nagar', 'Mumbai', 'Thane', 'Pune', 'Nashik', 'Hyderabad',
#        'Shamshabad', 'Bengaluru', 'Bangalore', 'Kolar', 'Chennai',
#        'Kanchipuram', 'Tiruvallur', 'Kolkata', 'Howrah', 'Hooghly'],
#       dtype=object)

# %%
final_lat_long = {}
for x in xs:
    print("cityname {}".format(x))
    lat_long = get_lat_long(x)
    final_lat_long[x] = lat_long
# Out:
# cityname Delhi
# {'results': [{'address_components': [{'long_name': 'Delhi', 'short_name': 'DL', 'types': ['administrative_area_level_1', 'locality', 'political']}, {'long_name': 'India', 'short_name': 'IN', 'types': ['country', 'political']}], 'formatted_address': 'Delhi, India', 'geometry': {'bounds': {'northeast': {'lat': 28.881338, 'lng': 77.3484578}, 'southwest': {'lat': 28.412593, 'lng': 76.83806899999999}}, 'location': {'lat': 28.7040592, 'lng': 77.10249019999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 28.881338, 'lng': 77.3484578}, 'southwest': {'lat': 28.412593, 'lng': 76.83806899999999}}}, 'place_id': 'ChIJLbZ-NFv9DDkRQJY4FbcFcgM', 'types': ['administrative_area_level_1', 'locality', 'political']}], 'status': 'OK'}
# Latitude:28.7040592
# Longitude:77.10249019999999
# Formatted Address:Delhi, India
# cityname Gurgaon
# ...

# %%
# d = {
#     'cityname': [],
#     'lat': [],
#     'long': []
# }
# for city in final_lat_long:
#     d['cityname'].append(city); d['lat'].append(final_lat_long[city][0])
#     d['long'].append(final_lat_long[city][1])

city_lat_long_all = pd.DataFrame(final_lat_long)

# %%
# city_lat_long_all = pd.DataFrame(d)

# %%
x = city_lat_long_all.T
x.index
# Out:
# Index(['Ahmedabad', 'Bangalore', 'Bengaluru', 'Chandigarh', 'Chennai', 'Delhi',
#        'Faridabad', 'Gandhi Nagar', 'Ghaziabad', 'Gurgaon', 'Hooghly',
#        'Howrah', 'Hyderabad', 'Jaipur', 'Kanchipuram', 'Kolar', 'Kolkata',
#        'Mohali', 'Mumbai', 'Nashik', 'Noida', 'Panchkula', 'Pune',
#        'Shamshabad', 'Thane', 'Tiruvallur'],
#       dtype='object')

# %%
city_lat_long_all.head()
# Out:
#    Ahmedabad  Bangalore  Bengaluru  Chandigarh    Chennai      Delhi  \
# 0  23.022505  12.971599  12.971599   30.733315  13.082680  28.704059
# 1  72.571362  77.594563  77.594563   76.779418  80.270718  77.102490
#
#    Faridabad  Gandhi Nagar  Ghaziabad    Gurgaon     ...        Kolkata  \
# 0  28.408912     23.215635  28.669156  28.459497     ...      22.572646
# 1  77.317789     72.636941  77.453758  77.026638     ...      88.363895
#
#       Mohali     Mumbai     Nashik      Noida  Panchkula       Pune  \
# 0  30.704649  19.075984  19.997453  28.535516  30.694209  18.520430
# 1  76.717873  72.877656  73.789802  77.391026  76.860565  73.856744
#
#    Shamshabad      Thane  Tiruvallur
# 0   17.251160  19.218331   13.254433
# 1   78.437735  72.978090   80.008775
#
# [2 rows x 26 columns]

# %%
city_lat_long_all
# Out:
#    Ahmedabad  Bangalore  Bengaluru  Chandigarh    Chennai      Delhi  \
# 0  23.022505  12.971599  12.971599   30.733315  13.082680  28.704059
# 1  72.571362  77.594563  77.594563   76.779418  80.270718  77.102490
#
#    Faridabad  Gandhi Nagar  Ghaziabad    Gurgaon     ...        Kolkata  \
# 0  28.408912     23.215635  28.669156  28.459497     ...      22.572646
# 1  77.317789     72.636941  77.453758  77.026638     ...      88.363895
#
#       Mohali     Mumbai     Nashik      Noida  Panchkula       Pune  \
# 0  30.704649  19.075984  19.997453  28.535516  30.694209  18.520430
# 1  76.717873  72.877656  73.789802  77.391026  76.860565  73.856744
#
#    Shamshabad      Thane  Tiruvallur
# 0   17.251160  19.218331   13.254433
# 1   78.437735  72.978090   80.008775
#
# [2 rows x 26 columns]

# %%
df4 =pd.read_csv('/home/prashant/Downloads/pincode/pincodes.csv')

# %%
df5 = pd.read_csv('/home/prashant/Downloads/pincode/missing_lat_long.csv')

# %%
results = df5.append(df4)

# %%
results.to_csv('merged_1.csv', index=False)

# %%
city_lat_long_all.to_csv('city_lat_long_all',index=False)

# %%
city_lat_long_all = pd.read_csv('city_lat_long_all')

# %%
city_lat_long_all.T.to_csv('city_lat_long_all', index=False)

# %%
res = pd.merge(df, city_lat_long_all, on='cityname')
df1.join(df2)

df3 = df1.set_index('p')

# %%
res
# Out:
#       pincode      districtname    statename  serviceable cityname        lat  \
# 0      110001     Central Delhi        DELHI            1    Delhi  28.704059
# 1      110002     Central Delhi        DELHI            1    Delhi  28.704059
# 2      110003     Central Delhi        DELHI            1    Delhi  28.704059
# 3      110004     Central Delhi        DELHI            1    Delhi  28.704059
# 4      110005     Central Delhi        DELHI            1    Delhi  28.704059
# 5      110006     Central Delhi        DELHI            1    Delhi  28.704059
# 6      110007       North Delhi        DELHI            1    Delhi  28.704059
# 7      110008     Central Delhi        DELHI            1    Delhi  28.704059
# 8      110009  North West Delhi        DELHI            1    Delhi  28.704059
# 9      110010  South West Delhi        DELHI            1    Delhi  28.704059
# 10     110011     Central Delhi        DELHI            1    Delhi  28.704059
# ...

# %%
res.to_csv('all_city_along_with_pincode_lat_long.csv', index=False)
