# %%
import pandas as pd

# %%
df =pd.read_csv('/home/prashant/Desktop/practice/practice_1.csv')

# %%
df.head(10)
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    Rebecca   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      Emily     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      Joyce    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     Justin  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     Andrew     Banks              AB4318@gmail.com         boots
# 5  52386      Julie     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     Thomas    Jensen              TJ5470@gmail.com         clogs
# 7  76971     Janice     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    Gabriel    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    Frances    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color
# 0  faux-leather      black
# 1  faux-leather       navy
# 2        fabric      black
# 3  faux-leather        red
# ...

# %%
df['shoe_type'] = df.shoe_type.apply(lambda x: x.lower())
df.head(10)
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    Rebecca   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      Emily     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      Joyce    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     Justin  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     Andrew     Banks              AB4318@gmail.com         boots
# 5  52386      Julie     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     Thomas    Jensen              TJ5470@gmail.com         clogs
# 7  76971     Janice     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    Gabriel    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    Frances    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color
# 0  faux-leather      black
# 1  faux-leather       navy
# 2        fabric      black
# 3  faux-leather        red
# ...

# %%
# !which python
# Out:
# /home/prashant/anaconda3/bin/python

# %%
df['first_name'] = df.first_name.apply(str.upper)
# ?string.upper()

# %%
df['first_name'] = df.first_name.apply(lambda x: x.upper())

# %%
df.head(10)
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    REBECCA   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      EMILY     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      JOYCE    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     JUSTIN  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     ANDREW     Banks              AB4318@gmail.com         boots
# 5  52386      JULIE     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     THOMAS    Jensen              TJ5470@gmail.com         clogs
# 7  76971     JANICE     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    GABRIEL    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    FRANCES    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color
# 0  faux-leather      black
# 1  faux-leather       navy
# 2        fabric      black
# 3  faux-leather        red
# ...

# %%
x = "fun"

# %%
x.lower
# Out:
# <function str.lower>

# %%
x.lower()
# Out:
# 'fun'

# %%
df['in_stock'] = df.shoe_material.apply(lambda x: False if x =="fabric" else True)

# %%
df.head(10)
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    REBECCA   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      EMILY     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      JOYCE    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     JUSTIN  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     ANDREW     Banks              AB4318@gmail.com         boots
# 5  52386      JULIE     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     THOMAS    Jensen              TJ5470@gmail.com         clogs
# 7  76971     JANICE     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    GABRIEL    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    FRANCES    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color  in_stock
# 0  faux-leather      black      True
# 1  faux-leather       navy      True
# 2        fabric      black     False
# ...

# %%
df['description'] =  df.apply(lambda row : "{} {} bought {} {} {}"\
                             .format(row.first_name,
                                     row.last_name,
                                     row.shoe_color,
                                     row.shoe_material,
                                     row.shoe_type),
                             axis=1)

# %%
df.head(10)
# Out:
#       id first_name last_name                         email     shoe_type  \
# 0  54791    REBECCA   Lindsay  RebeccaLindsay57@hotmail.com         clogs
# 1  53450      EMILY     Joyce        EmilyJoyce25@gmail.com  ballet flats
# 2  91987      JOYCE    Waller        Joyce.Waller@gmail.com       sandals
# 3  14437     JUSTIN  Erickson   Justin.Erickson@outlook.com         clogs
# 4  79357     ANDREW     Banks              AB4318@gmail.com         boots
# 5  52386      JULIE     Marsh        JulieMarsh59@gmail.com       sandals
# 6  20487     THOMAS    Jensen              TJ5470@gmail.com         clogs
# 7  76971     JANICE     Hicks        Janice.Hicks@gmail.com         clogs
# 8  21586    GABRIEL    Porter     GabrielPorter24@gmail.com         clogs
# 9  62083    FRANCES    Palmer     FrancesPalmer50@gmail.com        wedges
#
#   shoe_material shoe_color  in_stock  \
# 0  faux-leather      black      True
# 1  faux-leather       navy      True
# 2        fabric      black     False
# ...
